# %%
import json
import fitz

# %%
with open('/home/vinhvq11/Desktop/PDF_extraction/data_process/benchmarks/all/layout/converted_alldoc_annotated_layout.json') as f:
    gt = json.load(f)
with open('/home/vinhvq11/Desktop/PDF_extraction/data_process/benchmarks/all/layout/alldoc_predicted_layout.json') as f:
    pred = json.load(f)

# %%
gt[0]
# Out:
# {'file_id': None,
#  'file_name': 'thongtu032021ttbttttthanghangchucdanhnghenghiepvienchucthongtintruyenthong.pdf',
#  'domain': 'law',
#  'is_valid': None,
#  'elements': [{'page': 0,
#    'training_set': 'train',
#    'annotated_label': 'useless',
#    'predicted_label': None,
#    'predicted_score': None,
#    'original_width': 596,
#    'original_height': 843,
#    'bbox': {'x': 13.907944837280368,
#     'y': 8.538341695851871,
#     'w': 73.06434034379483,
#     'h': 5.590741301311718}},
#   {'page': 0,
#    'training_set': 'train',
#    'annotated_label': 'title',
#    'predicted_label': None,
#    'predicted_score': None,
#    'original_width': 596,
#    'original_height': 843,
#    'bbox': {'x': 13.025599462181967,
#     'y': 16.59336953563852,
#     'w': 74.3520829351264,
#     'h': 4.350731907522394}},
#   {'page': 0,
#    'training_set': 'train',
#    'annotated_label': 'text',
#    'predicted_label': None,
#    'predicted_score': None,
#    'original_width': 596,
# ...

# %%
doc = fitz.open('1.pdf')

# %%
text = ''
for page in doc:
    text+=page.get_text('word', sort=True)

# %%
text
with open('1.txt','w',encoding='utf-8') as f:
    f.write(text)

# %% [markdown]
# ## 2-column document

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/vinhvq11/Downloads/bc0b9fa7-3bc8-49c1-b015-7384902665f_qms 1.csv')

# %%
df
# Out:
#        metadata.external.effectiveDate  \
# 0           Jul 1, 2024 @ 07:00:00.000
# 1           Jul 1, 2024 @ 07:00:00.000
# 2           Jul 1, 2024 @ 07:00:00.000
# 3          Jun 21, 2024 @ 07:00:00.000
# 4          Jun 21, 2024 @ 07:00:00.000
# ...                                ...
# 117775     Aug 15, 2001 @ 07:00:00.000
# 117776     Aug 15, 2001 @ 07:00:00.000
# 117777     Aug 15, 2001 @ 07:00:00.000
# 117778     Aug 15, 2001 @ 07:00:00.000
# 117779     Aug 15, 2001 @ 07:00:00.000
#
#                                             content.title  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       3. Mục lục - 1 5 Kỷ luật "Thép" 2 Quy định xử ...
# 4       3. Mục lục - 1 5 Kỷ luật "Thép" 2 Quy định xử ...
# ...                                                   ...
# 117775  Code: 01e-CV/DE/HDCV/FSOFT JOB DESCRIPTION Iss...
# ...
