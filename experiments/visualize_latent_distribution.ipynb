# %%
import torch
import matplotlib.pyplot as plt

# Giả sử bạn có một tensor feature map với kích thước torch.Size([1, 256, 160, 160])
feature_maps = [torch.load(f'../../data/features/p{i}Thong_tin_Vacxin_TT_Long_Chau.pdf.pt') for i in range(2,7)]

# Chọn batch đầu tiên

# Trực quan hóa 6 feature maps đầu tiên
num_feature_maps_to_plot = 10
plt.figure(figsize=(15, 15))
fig, ax = plt.subplots(5, 10, figsize=(10, 6))

for i in range(5):
    # plt.subplot(10, 1, i+1)
    ax[i][0].set_title(f'Feature Map p{i+2}')
    for j in range(num_feature_maps_to_plot):
        # plt.imshow(feature_maps[i][0][j].detach().cpu().numpy(), cmap='viridis')
        # plt.title(f'Feature Map p{i+2}')

        # plt.axis('off')
    

        # Plot the first feature map
        ax[i][j].imshow(feature_maps[i][0][j].detach().cpu().numpy(), cmap='viridis')
        # ax[i][j].set_title(f'Feature Map p{i+2}')
        ax[i][j].axis('off')

# Show the plot
plt.show()

# %% [markdown]
# # 2. Similarity Metric
