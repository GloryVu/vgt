# %%
import os
import shutil

# %%
for root, dirs, files in sorted(os.walk('data')):
    for file in files:
        if '.pdf' in file.lower():
            shutil.copy2(os.path.join(root, file), 'data')

# %%
for root, dirs, files in sorted(os.walk('data')):
    for file in files:

# %%
import numpy as np
data = np.load('data/grid_pkl/3.-Thông-tư-01-2018-TT-VPCP-về-thực-hiện-cơ-chế-một-cửa_-MCLT.pdf_page_0.pdf.pkl',allow_pickle=True)

# %%
data
# Out:
# {'input_ids': array([118720, 234617,     64,    294,  54030,    209,  14546,    997,
#          36225,  74758,  69656,   1298,     53,   5742,  31435,   1742,
#           8934, 210487,  24784,  54958,   8066, 213099,  24784, 208240,
#         210487,  24784,  54958,   8066, 213099,  24784, 208240,    313,
#         249972,   8066,    572,  54958,    284,   1193,   7492, 203871,
#         230053,  22499,    841, 240898,    284, 163559,  75033,  56523,
#            238,  12552,     20, 117164,     54,     20, 193721,  55324,
#          48003,     12,   3413,  18242,     64,  13739,      9,  41195,
#          17854,   8548,   9435,      4,   3063,   1105,   7973,    534,
#           2933,    267, 163228, 157872,  48587,  10284,   6117,   4893,
#            889,   3030,   8317,   2931,    550,  83304,   2931,   3030,
#          11716,  18242,     64, 172719,      9,  17854,   3063,   1105,
#           7973,    201,   2933,    267,    550,  17654,  29798,   1893,
# ...
